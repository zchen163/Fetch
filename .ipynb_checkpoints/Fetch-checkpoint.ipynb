# %% [markdown]
# # Fetch Project: Similarity Search
#
# Prepared and presented by Chen Zhang

# %% [markdown]
# ## 1. Data Cleaning
#
# The first step is data cleaning. One of the key steps in processing language data is to remove noise so that the machine can more easily detect the patterns in the data.
#
# Text data contains a lot of noise, this takes the form of special characters. All of which are difficult for computers to understand if they are present in the data. We need to, therefore, process the data to remove these elements.
#
# Additionally, it is also important to apply some attention to the casing of words. If we include both upper case and lower case versions of the same words then the computer will see these as different entities, even though they may be the same.
#
# One example is shown in the snapshot of the offer_retailer.csv file below. Note that some items starts with a column character, and the 2nd and 3rd row has only difference with a capital letter 'L'.
#
# ![image.png](attachment:image.png)
#
# The code below performs these steps. To keep a track of the changes we are making to the text I have put the clean text into a new column. The output is shown below the code.

# %%
import numpy as np
import pandas as pd
import re

def clean(file): 
    # change to lower case
    df = pd.read_csv(file, dtype = str)
    for col in df.columns.values: 
        df[col] = df[col].str.lower()
    
    # remove special characters in the offer column
    if file == 'offer_retailer.csv': 
        for index, row in df.iterrows():
            txt = row['OFFER']
            df.loc[index, "OFFER"] = re.sub(r"[^a-z0-9 ]", "", txt)
    # remove duplicate rows
        df.drop_duplicates(subset=['OFFER'], inplace = True)
    return df

# %% [markdown]
# The three datasets are shown below, after cleaning. Note that a few lines in the offer_retailer file are removed due to duplication. The missing values in the 'Retailer' column are filled with empty strings. The some columns are also re-named for the purpose of future joining.

# %%
# Offer_brand table
offer = clean('offer_retailer.csv')
offer.replace(np.nan,'',regex=True, inplace=True)
print(offer.head())
print(offer.shape)
# Out:
#                                                OFFER            RETAILER  \
# 0       spend 50 on a fullpriced new club membership           sams club
# 1           beyond meat plantbased products spend 25
# 2           good humor viennetta frozen vanilla cake
# 3  butterball select varieties spend 10 at dillon...  dillons food store
# 4  gatorade fast twitch 12ounce 12 pack at amazon...              amazon
#
#          BRAND
# 0    sams club
# 1  beyond meat
# 2   good humor
# 3   butterball
# 4     gatorade
# (369, 3)

# %%
brand = clean('brand_category.csv')
brand.rename(columns={"BRAND_BELONGS_TO_CATEGORY": "CATEGORY"}, inplace=True)
# for index, row in brand.iterrows():
#     txt1 = row['CATEGORY']
#     brand.loc[index, "CATEGORY"] = re.sub(r"[^a-z0-9 ]", "", txt1)
print(brand.head())
print(brand.shape)
# Out:
#               BRAND          CATEGORY RECEIPTS
# 0  caseys gen store  tobacco products  2950931
# 1  caseys gen store            mature  2859240
# 2            equate      hair removal   893268
# 3         palmolive       bath & body   542562
# 4              dawn       bath & body   301844
# (9906, 3)

# %%
category = clean('categories.csv')
category.rename(columns={"PRODUCT_CATEGORY": "CATEGORY", 
                      "IS_CHILD_CATEGORY_TO": "PARENT_CATEGORY"}, inplace=True)
# for index, row in category.iterrows():
#     txt1 = row['CATEGORY']
#     category.loc[index, "CATEGORY"] = re.sub(r"[^a-z0-9 ]", "", txt1)
#     txt2 = row['PARENT_CATEGORY']
#     category.loc[index, "PARENT_CATEGORY"] = re.sub(r"[^a-z0-9 ]", "", txt2)

category.drop(columns=['CATEGORY_ID'], inplace = True)

print(category.head())
print(category.shape)
# Out:
#                       CATEGORY    PARENT_CATEGORY
# 0              red pasta sauce        pasta sauce
# 1  alfredo & white pasta sauce        pasta sauce
# 2             cooking & baking             pantry
# 3             packaged seafood             pantry
# 4             feminine hygeine  health & wellness
# (118, 2)

# %% [markdown]
# ## 2. Table merge
#
# I'd like to join all table into one major table for better handling.

# %%
# join the brand and category table, using pandas merge function which is equal to SQL inner join
brand_cat = brand.merge(category, right_on = ['CATEGORY'], left_on = ['CATEGORY'])

print(f'After joining the category (shape {category.shape}) and brand table (shape {brand.shape}), the output has shape of {brand_cat.shape}')
print(brand_cat.head())
# Out:
# After joining the category (shape (118, 2)) and brand table (shape (9906, 3)), the output has shape of (9906, 4)
#                BRAND          CATEGORY RECEIPTS    PARENT_CATEGORY
# 0   caseys gen store  tobacco products  2950931             mature
# 1  rj reynolds vapor  tobacco products       21             mature
# 2   caseys gen store            mature  2859240             mature
# 3             equate      hair removal   893268  health & wellness
# 4           barbasol      hair removal   283926  health & wellness

# %%
full = offer.merge(brand_cat, right_on = ['BRAND'], left_on = ['BRAND'])

# rearrange columns
cols = ['OFFER', 'RETAILER', 'BRAND', 'CATEGORY', 'PARENT_CATEGORY', 'RECEIPTS']
full = full[cols]
print(full)
print(full.shape)
# Out:
#                                                  OFFER  \
# 0             beyond meat plantbased products spend 25
# 1             beyond meat plantbased products spend 25
# 2             beyond meat plantbased products spend 25
# 3    beyond steak plantbased seared tips 10 ounce a...
# 4    beyond steak plantbased seared tips 10 ounce a...
# 5    beyond steak plantbased seared tips 10 ounce a...
# 6    beyond steak plantbased seared tips 10 ounce b...
# 7    beyond steak plantbased seared tips 10 ounce b...
# 8    beyond steak plantbased seared tips 10 ounce b...
# 9    beyond steak plantbased seared tips 10 ounce a...
# 10   beyond steak plantbased seared tips 10 ounce a...
# 11   beyond steak plantbased seared tips 10 ounce a...
# 12   beyond steak plantbased seared tips 10 ounce b...
# 13   beyond steak plantbased seared tips 10 ounce b...
# 14   beyond steak plantbased seared tips 10 ounce b...
# 15            beyond meat plantbased products spend 15
# 16            beyond meat plantbased products spend 15
# 17            beyond meat plantbased products spend 15
# 18            beyond meat plantbased products spend 20
# 19            beyond meat plantbased products spend 20
# 20            beyond meat plantbased products spend 20
# 21            good humor viennetta frozen vanilla cake
# 22            good humor viennetta frozen vanilla cake
# 23   reeses peanut butter bar 6 count at giant or m...
# 24   reeses peanut butter bar 6 count at giant or m...
# 25   butterball select varieties spend 10 at dillon...
# 26   butterball select varieties spend 10 at dillon...
# 27      butterball select varieties spend 10 at ralphs
# 28      butterball select varieties spend 10 at ralphs
# 29   butterball select varieties spend 10 at ruler ...
# 30   butterball select varieties spend 10 at ruler ...
# 31   butterball select varieties spend 10 at king s...
# 32   butterball select varieties spend 10 at king s...
# 33   butterball select varieties spend 10 at fred m...
# 34   butterball select varieties spend 10 at fred m...
# 189                                 spend 300 at shaws
# 190  loral paris hair color select varieties spend ...
# 191  loral paris men expert hair color spend 19 at ...
# 192  loral paris men expert hair color spend 9 at w...
# 193        loral paris excellence hair color at target
# 194  loral paris hair color select varieties spend ...
# 195  loral paris hair color select varieties spend ...
# 196                     simply spiked lemonade 12 pack
# 197                     simply spiked lemonade 12 pack
# 198  simply spiked signature peach 12pack or larger...
# 199  simply spiked signature peach 12pack or larger...
# 200                              simply spiked 12 pack
# 201                              simply spiked 12 pack
# 202              simply spiked signature peach 12 pack
# 203              simply spiked signature peach 12 pack
# 204                        gortons at select retailers
# 205                        gortons at select retailers
# 206                        gortons at select retailers
# 207      gortons air fried butterfly shrimp at walmart
# 208      gortons air fried butterfly shrimp at walmart
# 209      gortons air fried butterfly shrimp at walmart
# 210                               shop 2 times at acme
# 211                                   spend 90 at acme
# 212                                  spend 250 at acme
# 213                                   any acme receipt
# 214                                  spend 130 at acme
# 215                 order from caseys app or caseyscom
# 216                 order from caseys app or caseyscom
# 217                                 spend 25 at caseys
# 218                                 spend 25 at caseys
# 219                          spend 5 instore at caseys
# 220                          spend 5 instore at caseys
# 221  select beverages and prepared food items at ca...
# 222  select beverages and prepared food items at ca...
# 223          visit or order online from caseys 7 times
# 224          visit or order online from caseys 7 times
# 225  spend 5 on singleserve prepared food items at ...
# 226  spend 5 on singleserve prepared food items at ...
# 227   12 pack or 2 liter and whole pizza pie at caseys
# 228   12 pack or 2 liter and whole pizza pie at caseys
# 229                              whole pizza at caseys
# 230                              whole pizza at caseys
# 231              wings or cheesy breadsticks at caseys
# 232              wings or cheesy breadsticks at caseys
# 233                          whole pizza pie at caseys
# 234                          whole pizza pie at caseys
# 235                 frozen or fountain drink at caseys
# 236                 frozen or fountain drink at caseys
# 237                         spend 10 instore at caseys
# 238                         spend 10 instore at caseys
# 239       fresh bakery item select varieties at caseys
# 240       fresh bakery item select varieties at caseys
# 241       12 pack or 2 liter and whole pizza at caseys
# 242       12 pack or 2 liter and whole pizza at caseys
# 243                frozen or fountain drink at caseys
# 244                frozen or fountain drink at caseys
# 245          visit or order online from caseys 3 times
# 246          visit or order online from caseys 3 times
# 247          visit or order online from caseys 5 times
# 248          visit or order online from caseys 5 times
# 249                             whole pizza at caseys
# 250                             whole pizza at caseys
# 251   fresh bakery products at caseys select varieties
# 252   fresh bakery products at caseys select varieties
# 253       spend 10 on caseys branded packaged products
# 254       spend 10 on caseys branded packaged products
# 255        2 pack or 2 liter and whole pizza at caseys
# 256        2 pack or 2 liter and whole pizza at caseys
# 257  select beverages and prepared food item at caseys
# 258  select beverages and prepared food item at caseys
# 259      fresh bakery items select varieties at caseys
# 260      fresh bakery items select varieties at caseys
# 261  spend 5 on brisket mac  cheese sandwich or oth...
# 262  spend 5 on brisket mac  cheese sandwich or oth...
# 263                  flonase allergy relief at walmart
# 264                        cesar wet dog food spend 20
# 265                        cesar wet dog food spend 20
# 266                        cesar wet dog food spend 20
# 267                        cesar wet dog food spend 20
# 344                    sara lee delightful bread buy 2
# 345                    sara lee delightful bread buy 2
# 346           sara lee or alfaros artesano bread buy 5
# 347           sara lee or alfaros artesano bread buy 5
# 348         sara lee or alfaros artesano bread spend 8
# 349         sara lee or alfaros artesano bread spend 8
# 350           sara lee or alfaros artesano bread buy 2
# 351           sara lee or alfaros artesano bread buy 2
# 352        sara lee or alfaros artesano bread spend 20
# 353        sara lee or alfaros artesano bread spend 20
# 354            bai antioxidant 6 pack buy 2 at walmart
# 355            bai antioxidant 6 pack buy 2 at walmart
# 356            bai antioxidant 6 pack buy 2 at walmart
# 357            bai antioxidant 6 pack buy 2 at walmart
# 358                  bai antioxidant 6 pack at walmart
# 359                  bai antioxidant 6 pack at walmart
# 360                  bai antioxidant 6 pack at walmart
# 361                  bai antioxidant 6 pack at walmart
# 362  reeses chocolate cones 8 count at giant or mar...
# 363  reeses chocolate cones 8 count at giant or mar...
# 364                klondike cones spend 10 at walmart
# 365                klondike cones spend 10 at walmart
# 366                         klondike cones at walmart
# 367                         klondike cones at walmart
# 368                             any albertsons receipt
# 369                         shop 2 times at albertsons
# 370                             spend 65 at albertsons
# 371                            spend 110 at albertsons
# 372                            spend 220 at albertsons
# 373  back to the roots grow seed starting pots or g...
# 374  back to the roots soils select varieties and s...
# 375  back to the roots dry plant food 5 pounds at t...
# 376  back to the roots garden soil 1 cubic foot at ...
# 377  back to the roots raised bed gardening kit wit...
# 378  back to the roots microgreens grow kit or seed...
# 379  back to the roots soils select varieties and s...
# 380  back to the roots soils select varieties at wa...
# 381  back to the roots grow kits at walmart or the ...
# 382  back to the roots grow hydroponic grow kit or ...
# 383                 back to the roots seeds at walmart
# 384  back to the roots organic kits and planters at...
# 385  back to the roots potting mix 1 cubic foot at ...
# 386  back to the roots organic 3in1 seed starting m...
# 387  back to the roots soils select varieties at wa...
# 388    dove hand wash select varieties buy 2 at target
# 389    dove hand wash select varieties buy 2 at target
# 390    dove hand wash select varieties buy 2 at target
# 391    dove hand wash select varieties buy 2 at target
# 392          dove hand wash select varieties at target
# 393          dove hand wash select varieties at target
# 394          dove hand wash select varieties at target
# 395          dove hand wash select varieties at target
# 396                           frutero ice cream 1 pint
# 397                           frutero ice cream 1 pint
# 398        biooil skincare oil or gel select varieties
# 399        biooil skincare oil or gel select varieties
# 400                   biooil products select varieties
# 401                   biooil products select varieties
# 402          welchsfruit snacks select varieties buy 2
# 403  welchs zero sugar fruity bites 6 pack online a...
# 404  welchs fruit snacks select varieties 6 count b...
# 405     welchs fruit snacks 250 count online at amazon
# 406  welchs juicefuls juicy fruit snacks 14 count a...
# 407  welchs fruit snacks select varieties 6 count b...
# 408                         welchsfruit snacks spend 8
# 409   welchs fruit n yogurt snacks 18 count at walmart
# 410       welchs fruit snacks select varieties 6 count
# 411          welchs juicefuls juicy fruit snacks buy 2
# 412                                  talenti mini bars
# 413                                  talenti mini bars
# 414              molson coors select varieties 12 pack
# 415              molson coors select varieties 12 pack
# 416  sign up for the club card or the club card ful...
# 494                            spend 60 at tgi fridays
# 495                            spend 60 at tgi fridays
# 496                            spend 35 at tgi fridays
# 497                            spend 35 at tgi fridays
# 498                            spend 35 at tgi fridays
# 499                            spend 45 at tgi fridays
# 500                            spend 45 at tgi fridays
# 501                            spend 45 at tgi fridays
# 502                            spend 25 at tgi fridays
# 503                            spend 25 at tgi fridays
# 504                            spend 25 at tgi fridays
# 505                     artesano buns buy 2 at walmart
# 506                     artesano buns buy 2 at walmart
# 507                       starburst select sizes buy 1
# 508                       starburst select sizes buy 1
# 509                       starburst select sizes buy 1
# 510                         starburst select varieties
# 511                         starburst select varieties
# 512                         starburst select varieties
# 513                   fresh step outstretch cat litter
# 514                   fresh step outstretch cat litter
# 515                   fresh step outstretch cat litter
# 516                   fresh step outstretch cat litter
# 517                   fresh step outstretch cat litter
# 518                   fresh step outstretch cat litter
# 519  burts bees sensitive lotions and creams select...
# 520  burts bees sensitive lotions and creams select...
# 521  burts bees sensitive lotions and creams select...
# 522  burts bees facial wipes select varieties 30 co...
# 523  burts bees facial wipes select varieties 30 co...
# 524  burts bees facial wipes select varieties 30 co...
# 525    burts bees products select varieties at walmart
# 526    burts bees products select varieties at walmart
# 527    burts bees products select varieties at walmart
# 528  durex massage  play 2 in 1 pleasure gel select...
# 529  durex massage  play 2 in 1 pleasure gel select...
# 530                                        life savers
# 531                          lifesavers any size buy 1
# 532                        respawn by 5 gum at walmart
# 533                                wesson oil products
# 534  bubbies pickles sauerkraut and condiments at w...
# 535  bubbies pickles sauerkraut or condiments at wh...
# 536                   michael angelos sauce at walmart
# 537                   michael angelos sauce at walmart
# 538                             spend 155 at pavilions
# 539                          shop 2 times at pavilions
# 540                             spend 100 at pavilions
# 541                              any pavilions receipt
# 542                             spend 270 at pavilions
# 543                   beechnut snacks select varieties
# 544                   beechnut snacks select varieties
# 545                   beechnut snacks select varieties
# 546                   beechnut snacks select varieties
# 547                             beechnut pouches buy 8
# 548                             beechnut pouches buy 8
# 549                             beechnut pouches buy 8
# 550                             beechnut pouches buy 8
# 551                           brita pitcher and filter
# 552                           brita pitcher and filter
# 553                    brita standard or elite filters
# 554                    brita standard or elite filters
# 555                         brita pitcher or dispenser
# 556                         brita pitcher or dispenser
# 557                            spend 90 at star market
# 558                        shop 2 times at star market
# 559                           spend 120 at star market
# 560                           spend 220 at star market
# 561                            any star market receipt
# 562                        snickers select sizes buy 1
# 563      snickers chocolate candy bar select varieties
# 564          kodiak products select varieties spend 10
# 565                               bays english muffins
# 566           super coffee 12 ounce single serve buy 3
# 567                 super coffee 12 ounce single serve
# 568                                 goya coconut water
# 569                                 goya coconut water
# 570                                 goya coconut water
# 571                                 goya coconut water
# 572                                 goya coconut water
# 573                                 goya coconut water
# 574                                 goya coconut water
# 575                                 goya coconut water
# 576                                 goya coconut water
# 577                                 goya coconut water
# 578                                 goya coconut water
# 579                                 goya coconut water
# 580                                 goya coconut water
# 581                                 goya coconut water
# 582                                 goya coconut water
# 656        kradle select varieties spend 20 at walmart
# 657          kradle select products online at chewycom
# 658          kradle select products online at chewycom
# 659           kradle select varieties online at amazon
# 660           kradle select varieties online at amazon
# 661       kradle select varieties at pet supplies plus
# 662       kradle select varieties at pet supplies plus
# 663  childrens astepro allergy 22 count at dollar g...
# 664   adult astepro allergy 22 count at dollar general
# 665                      bimbo sweet baked goods buy 2
# 666                      bimbo sweet baked goods buy 2
# 667                      bimbo sweet baked goods buy 2
# 668                      bimbo sweet baked goods buy 2
# 669                           natuchips plantain chips
# 670                   promised land dairy milk 52ounce
# 671         core hydration select varieties at walmart
# 672   core hydration select varieties buy 2 at walmart
# 673  colgate toothpaste and colgate toothbrush sele...
# 674                             extra select varieties
# 675                                 extra select sizes
# 676                   wonderworks keto friendly cereal
# 677  mtn dew kickstart 16ounce 12 count select vari...
# 678                          skittles select varieties
# 679                          skittles select varieties
# 680                              skittles select sizes
# 681                              skittles select sizes
# 682  stubborn soda or bundaberg ginger beer select ...
# 683                                ballpark buns buy 2
# 684                                ballpark buns buy 2
# 685                           orbit select sizes buy 1
# 686                             orbit select varieties
# 687        molson coors select varieties 12 pack buy 2
# 688        starry lemon lime soda multipacks at kroger
# 689  starry lemon lime soda 75ounce 10 pack at amaz...
# 690  evolve plantbased protein shake 4 count select...
# 691  evolve plantbased protein shake 4 count select...
# 692  evolve plantbased protein shake 4 count select...
# 693  tyson products select varieties spend 15 at wa...
# 694               hagendazs 28 ounce at grocery stores
# 695                      glad trash bags 4 or 8 gallon
# 696                      glad trash bags 4 or 8 gallon
# 697                      glad trash bags 4 or 8 gallon
# 698                      glad trash bags 4 or 8 gallon
# 699             glad forceflex max strength trash bags
# 700             glad forceflex max strength trash bags
# 701             glad forceflex max strength trash bags
# 702             glad forceflex max strength trash bags
# 703                                   tostitos toppers
# 704                                   tostitos toppers
# 705                                   tostitos toppers
# 706              ratio keto friendly cereal or granola
# 707              ratio keto friendly cereal or granola
# 708              ratio keto friendly cereal or granola
# 709  andr california champagne or sparkling wines 7...
# 710                  degree for men or women dry spray
# 711      brownie brittle snacks select varieties buy 2
# 712      brownie brittle snacks select varieties buy 2
# 713                   cheerios oat crunch berry cereal
# 714                                    spend 10 at cvs
# 715                                    spend 10 at cvs
# 716                                    spend 10 at cvs
# 717                                    spend 10 at cvs
# 718                                    spend 30 at cvs
# 719                                    spend 30 at cvs
# 720                                    spend 30 at cvs
# 721                                    spend 30 at cvs
# 722          snuggle liquid fabric softener at walmart
# 723        general mills snacks select brands spend 10
# 724                              the rustik oven bread
# 725                      nature valley protein granola
# 726                      nature valley protein granola
# 727                      nature valley protein granola
# 728                      nature valley protein granola
# 729                      nature valley protein granola
# 730                      nature valley protein granola
# 731                      nature valley protein granola
# 732                      nature valley protein granola
# 733                      nature valley protein granola
# 734                      nature valley protein granola
# 735                   sir kensingtons condiments buy 2
# 736                   sir kensingtons condiments buy 2
# 737                   sir kensingtons condiments buy 2
# 738                         sir kensingtons condiments
# 739                         sir kensingtons condiments
# 740                         sir kensingtons condiments
# 741                            spend 15 at burger king
# 742                            camerons coffee ecopods
# 743    dixon safety carpenter pencil 10 count at lowes
# 744    dixon safety carpenter pencil 10 count at lowes
# 745  breyers reeses ice cream select varieties at g...
# 746  breyers reeses ice cream select varieties at g...
# 747                        jack links select varieties
# 748           simply organic seasoning mixes or spices
# 749           simply organic seasoning mixes or spices
#
#                    RETAILER                               BRAND  \
# 0                                                   beyond meat
# 1                                                   beyond meat
# 2                                                   beyond meat
# 3                    target                         beyond meat
# 4                    target                         beyond meat
# 5                    target                         beyond meat
# 6                     h-e-b                         beyond meat
# 7                     h-e-b                         beyond meat
# 8                     h-e-b                         beyond meat
# 9                     h-e-b                         beyond meat
# 10                    h-e-b                         beyond meat
# 11                    h-e-b                         beyond meat
# 12                   target                         beyond meat
# 13                   target                         beyond meat
# 14                   target                         beyond meat
# 15                                                  beyond meat
# 16                                                  beyond meat
# 17                                                  beyond meat
# 18                                                  beyond meat
# 19                                                  beyond meat
# 20                                                  beyond meat
# 21                                                   good humor
# 22                                                   good humor
# 23             the giant co                          good humor
# 24             the giant co                          good humor
# 25       dillons food store                          butterball
# 26       dillons food store                          butterball
# 27                   ralphs                          butterball
# 28                   ralphs                          butterball
# 29              ruler foods                          butterball
# 30              ruler foods                          butterball
# 31             king soopers                          butterball
# 32             king soopers                          butterball
# 33               fred meyer                          butterball
# 34               fred meyer                          butterball
# 35                   kroger                          butterball
# 36                   kroger                          butterball
# 37                   smiths                          butterball
# 38                   smiths                          butterball
# 39                food4less                          butterball
# 40                food4less                          butterball
# 41          frys food store                          butterball
# 42          frys food store                          butterball
# 43                      qfc                          butterball
# 44                      qfc                          butterball
# 45                 marianos                          butterball
# 46                 marianos                          butterball
# 47              pick n save                          butterball
# 48              pick n save                          butterball
# 49                   amazon                            gatorade
# 50                   amazon                            gatorade
# 51                   amazon                            gatorade
# 52                                                     gatorade
# 53                                                     gatorade
# 54                                                     gatorade
# 55               fred meyer                            gatorade
# 56               fred meyer                            gatorade
# 57               fred meyer                            gatorade
# 58                                                     gatorade
# 59                                                     gatorade
# 60                                                     gatorade
# 61          dillons grocery                            gatorade
# 62          dillons grocery                            gatorade
# 63          dillons grocery                            gatorade
# 64                                                     gatorade
# ...
# 417                           snacks     3132
# 418                           snacks      254
# 419                           snacks     3186
# 420                          alcohol      857
# 421                          alcohol     1385
# 422                          alcohol      857
# 423                          alcohol     1385
# 424                          alcohol      857
# 425                          alcohol     1385
# 426                          alcohol      857
# 427                          alcohol     1385
# 428                          alcohol      857
# 429                          alcohol     1385
# 430                    deli & bakery       47
# 431                           snacks    21898
# 432                          alcohol      142
# 433                           snacks      382
# 434                           snacks       25
# 435                           pantry      418
# 436                           frozen    18085
# 437                           frozen    18085
# 438                           frozen    18085
# 439                           frozen    18085
# 440                           frozen    18085
# 441                           frozen    18085
# 442                           frozen    18085
# 443                           frozen    18085
# 444               household supplies       18
# 445                           snacks      529
# 446                           snacks      529
# 447                           snacks      529
# 448                           snacks      529
# 449                           snacks      529
# 450                          alcohol       74
# 451                  pasta & noodles      512
# 452                           pantry     2382
# 453                           frozen       53
# 454                      pasta sauce      167
# 455                           frozen      498
# 456                      pasta sauce      276
# 457                           pantry      113
# 458                  pasta & noodles      512
# 459                           pantry     2382
# 460                           frozen       53
# 461                      pasta sauce      167
# 462                           frozen      498
# 463                      pasta sauce      276
# 464                           pantry      113
# 465                  pasta & noodles      512
# 466                           pantry     2382
# 467                           frozen       53
# 468                      pasta sauce      167
# 469                           frozen      498
# 470                      pasta sauce      276
# 471                           pantry      113
# 472                            dairy    22912
# 473                            dairy    22912
# 474                            dairy    22912
# 475                            dairy    22912
# 476                            dairy    22912
# 477                            dairy    22912
# 478                           pantry     2130
# 479                           pantry     2130
# 480                health & wellness     2594
# 481                health & wellness     2594
# 482                health & wellness     2594
# 483                           frozen     2257
# 484                    deli & bakery       24
# 485                           frozen      258
# 486                           pantry    26490
# 487                    deli & bakery       24
# 488                           frozen      258
# 489                           pantry    26490
# 490                    deli & bakery       24
# 491                           frozen      258
# 492                           pantry    26490
# 493                          alcohol      245
# 494                          alcohol       33
# 495                           frozen      403
# 496                          alcohol      245
# 497                          alcohol       33
# 498                           frozen      403
# 499                          alcohol      245
# 500                          alcohol       33
# 501                           frozen      403
# 502                          alcohol      245
# 503                          alcohol       33
# 504                           frozen      403
# 505                    deli & bakery     7912
# 506                           pantry     1806
# 507                           snacks    11713
# 508                           snacks      486
# 509                            candy       81
# 510                           snacks    11713
# 511                           snacks      486
# 512                            candy       81
# 513                health & wellness      109
# 514                    deli & bakery     1717
# 515                           beauty      256
# 516                health & wellness     2445
# 517                           pantry       44
# 518                health & wellness       40
# 519                health & wellness       90
# 520                           beauty     1210
# 521                health & wellness      160
# 522                health & wellness       90
# 523                           beauty     1210
# 524                health & wellness      160
# 525                health & wellness       90
# 526                           beauty     1210
# 527                health & wellness      160
# 528                health & wellness      376
# 529                health & wellness       12
# 530                           snacks    14431
# 531                           snacks    14431
# 532                            candy     4813
# 533                           pantry     1416
# 534                    deli & bakery      600
# 535                    deli & bakery      600
# 536                           pantry       27
# 537                           frozen      461
# 538                           pantry       15
# 539                           pantry       15
# 540                           pantry       15
# 541                           pantry       15
# 542                           pantry       15
# 543                           snacks       45
# 544                           snacks      355
# 545                           snacks     3732
# 546                           snacks       24
# 547                           snacks       45
# 548                           snacks      355
# 549                           snacks     3732
# 550                           snacks       24
# 551               household supplies       20
# 552                        beverages       24
# 553               household supplies       20
# 554                        beverages       24
# 555               household supplies       20
# 556                        beverages       24
# 557                           pantry       35
# 558                           pantry       35
# 559                           pantry       35
# 560                           pantry       35
# 561                           pantry       35
# 562                           snacks    23740
# 563                           snacks    23740
# 564                           pantry      104
# 565                           pantry     1066
# 566                        beverages     1232
# 567                        beverages     1232
# 568                        beverages       28
# 569                           snacks       61
# 570                           pantry    28252
# 571                           pantry      258
# 572                           pantry       17
# 573                        beverages      171
# 574                  pasta & noodles      450
# 575                      frozen meat       33
# 576                        beverages      850
# 577                          alcohol       68
# 578                           pantry     3469
# 579                           pantry     1056
# 580                           pantry     4204
# 581                           snacks       12
# 582                           pantry      785
# 583                           snacks      471
# 584                           frozen      138
# 585                           pantry      186
# 586                           frozen      512
# 587                        beverages      252
# 588                            dairy       46
# 589                           frozen      256
# 590                           pantry       83
# 591                           pantry       40
# 592                           snacks       32
# 593                           pantry       17
# 594                    deli & bakery       59
# 595                      frozen meat       21
# 596                           frozen       90
# 597                        beverages       28
# 598                           snacks       61
# 599                           pantry    28252
# 600                           pantry      258
# 601                           pantry       17
# 602                        beverages      171
# 603                  pasta & noodles      450
# 604                      frozen meat       33
# 605                        beverages      850
# 606                          alcohol       68
# 607                           pantry     3469
# 608                           pantry     1056
# 609                           pantry     4204
# 610                           snacks       12
# 611                           pantry      785
# 612                           snacks      471
# 613                           frozen      138
# 614                           pantry      186
# 615                           frozen      512
# 616                        beverages      252
# 617                            dairy       46
# 618                           frozen      256
# 619                           pantry       83
# 620                           pantry       40
# 621                           snacks       32
# 622                           pantry       17
# 623                    deli & bakery       59
# 624                      frozen meat       21
# 625                           frozen       90
# 626                           pantry       19
# 627                    deli & bakery     2808
# 628                        beverages     7387
# 629                           snacks       60
# 630                        beverages      762
# 631                    deli & bakery    36533
# 632                           snacks     1262
# 633                          alcohol    16286
# 634                           snacks     5289
# 635                            dairy     6224
# 636                           pantry     2320
# 637                           pantry       49
# 638                        beverages    11220
# 639                      frozen meat     1564
# 640                        beverages    19776
# 641                    deli & bakery    21413
# 642                        beverages     4804
# 643                           snacks      361
# 644                           pantry      247
# 645                           snacks     8133
# 646                           frozen      351
# 647                           pantry     1668
# 648                            dairy     4223
# 649                           pantry      464
# 650                           pantry     2145
# 651                           pantry     1987
# 652                           pantry     1059
# 653                           pantry       44
# 654                      frozen meat       24
# 655                           pantry       91
# 656           animals & pet supplies       19
# 657                           pantry       91
# 658           animals & pet supplies       19
# 659                           pantry       91
# 660           animals & pet supplies       19
# 661                           pantry       91
# 662           animals & pet supplies       19
# 663                health & wellness      313
# 664                health & wellness      313
# 665                    deli & bakery       57
# 666                           snacks     3914
# 667                           pantry     2324
# 668                           snacks       42
# 669                           snacks      129
# 670                            dairy       32
# 671                        beverages     4595
# 672                        beverages     4595
# 673                health & wellness     2172
# 674                            candy    12828
# 675                            candy    12828
# 676                           pantry      100
# 677                        beverages    68610
# 678                           snacks    15809
# 679                        beverages       74
# 680                           snacks    15809
# 681                        beverages       74
# 682                        beverages       16
# 683                    deli & bakery     5920
# 684                           pantry     9922
# 685                            candy     7268
# 686                            candy     7268
# 687                          alcohol     4175
# 688                        beverages     2851
# 689                        beverages     2851
# 690                        beverages     1242
# 691                        beverages       37
# 692                      frozen meat       20
# 693                           pantry      854
# 694                           frozen      301
# 695               household supplies     6822
# 696                    deli & bakery     1350
# 697                           snacks      835
# 698               household supplies      268
# 699               household supplies     6822
# 700                    deli & bakery     1350
# 701                           snacks      835
# 702               household supplies      268
# 703                           snacks     9299
# 704                           snacks    21401
# 705                           pantry       30
# 706                           pantry     1080
# 707                            dairy     1131
# 708                           snacks      120
# 709                          alcohol      614
# 710                health & wellness     4674
# 711                    deli & bakery      563
# 712                           snacks      229
# 713                           pantry    10876
# 714                health & wellness    39210
# 715                           pantry       45
# 716                        beverages       75
# 717                health & wellness       44
# 718                health & wellness    39210
# 719                           pantry       45
# 720                        beverages       75
# 721                health & wellness       44
# 722               household supplies     2214
# 723                           snacks     3654
# 724                           pantry      292
# 725                           snacks      440
# 726                           snacks     1524
# 727                           snacks      105
# 728                           pantry     2532
# 729                           pantry      684
# 730                           snacks     4455
# 731                           snacks      332
# 732                           snacks     3637
# 733                           snacks     1979
# 734                           snacks      370
# 735                           pantry       87
# 736                           pantry      954
# 737                           pantry       22
# 738                           pantry       87
# 739                           pantry      954
# 740                           pantry       22
# 741                           pantry      272
# 742                        beverages      393
# 743                           beauty     1043
# 744                           pantry     6752
# 745                           frozen    16732
# 746                           frozen     1678
# 747                           snacks     1614
# 748                           pantry     1440
# 749                           pantry      413
# (750, 6)

# %% [markdown]
# It's worth noting that the major table has duplicate rows for some categories that belongs to more than one parent category. One example is frozen pizza is under both 'frozen' and 'pantry' parent_category, which makes sense. Another point is, I use inner join for simple search. With the above major table ready, I will move forward and seek for input similarity search.

# %% [markdown]
# ## 3. Similarity Search Based on Fuzzy String - Baseline Method

# %% [markdown]
# A few critieria including ratio, partial ratio, token sort ratio, token set ratio, and partial token sort ratio, are being tested. One example is shown below using 'meat' as the input.

# %%
from thefuzz import fuzz

name = "meat"
similarity = category.copy()
partialRatio, ratio, tokenSortRatio, tokenSetRatio, partialTokenSortRatio = [], [], [], [], []

# for criteria in ['Ratio', 'Partial Ratio', 'Token Sort Ratio', 'Token Set Ratio', 'Partial Token Set Ratio']: 
#     print(similarity['CATEGORY'].nlargest(10, criteria))

for index, row in similarity.iterrows():
    val = row['CATEGORY']
#     full_name = "Kurtis K D Pykes"
    a = fuzz.partial_ratio(name, val)
    b = fuzz.ratio(name, val)
    c = fuzz.token_sort_ratio(name, val)
    d = fuzz.token_set_ratio(name, val)
    e = fuzz.partial_token_sort_ratio(name, val)
    partialRatio.append(a)
    ratio.append(b)
    tokenSortRatio.append(c)
    tokenSetRatio.append(d)
    partialTokenSortRatio.append(e)
similarity['Partial Ratio'] = partialRatio
similarity['Ratio'] = ratio
similarity['Token Sort Ratio'] = tokenSortRatio
similarity['Token Set Ratio'] = tokenSetRatio
similarity['Partial Token Set Ratio'] = partialTokenSortRatio

for criteria in ['Ratio', 'Partial Ratio', 'Token Sort Ratio', 'Token Set Ratio', 'Partial Token Set Ratio']: 
    print(f'Top 10 matched category using {criteria}')
    print(similarity.nlargest(10, criteria)[['CATEGORY', criteria]])
    print()
# Out:
# Top 10 matched category using Ratio
#              CATEGORY  Ratio
# 112            mature     60
# 52                tea     57
# 90      packaged meat     47
# 6               cream     44
# 51              bread     44
# 71              water     44
# 23         condiments     43
# 72   plant-based meat     40
# 74        fresh pasta     40
# 92             makeup     40
#
# Top 10 matched category using Partial Ratio
#                        CATEGORY  Partial Ratio
# 47           jerky & dried meat            100
# 72             plant-based meat            100
# 90                packaged meat            100
# 105     frozen plant-based meat            100
# 16   meal replacement beverages             75
# 19                 frozen meals             75
# 23                   condiments             75
# 24       packaged meals & sides             75
# 35                sexual health             75
# 36               malt beverages             75
#
# Top 10 matched category using Token Sort Ratio
#                CATEGORY  Token Sort Ratio
# 112              mature                60
# 52                  tea                57
# 90        packaged meat                47
# 6                 cream                44
# 51                bread                44
# 71                water                44
# 23           condiments                43
# 18          snack mixes                40
# 47   jerky & dried meat                40
# 72     plant-based meat                40
#
# Top 10 matched category using Token Set Ratio
#                     CATEGORY  Token Set Ratio
# 47        jerky & dried meat              100
# 72          plant-based meat              100
# 90             packaged meat              100
# 105  frozen plant-based meat              100
# 112                   mature               60
# 52                       tea               57
# 6                      cream               44
# 51                     bread               44
# 71                     water               44
# 23                condiments               43
#
# Top 10 matched category using Partial Token Set Ratio
#                        CATEGORY  Partial Token Set Ratio
# 47           jerky & dried meat                      100
# 72             plant-based meat                      100
# 90                packaged meat                      100
# 105     frozen plant-based meat                      100
# 16   meal replacement beverages                       75
# 19                 frozen meals                       75
# 23                   condiments                       75
# 24       packaged meals & sides                       75
# 35                sexual health                       75
# 36               malt beverages                       75

# %% [markdown]
# Even if the first couple top-matched items contain word 'meat', but other matched words don't make too much sense. This is because the nature of fuzzy search is edit distance. for example, from 'meat' to 'meal', there is only one letter difference, thus the edit distance is 1.

# %% [markdown]
# ## 4. Similarity Search Using Transfomer - Improved Method

# %% [markdown]
# Text/Sentence similarity is one of the clearest examples of how powerful transformer models can be. Here the NLP solution will take some query text, process it to create an embeddings using pre-trained model, and compute the similarity between the query text and the target field (e.g. category column). A few well-established models are evaluated including 'all-MiniLM-L6-v2', 'all-mpnet-base-v2', 'all-distilroberta-v1', and 'bert-base-nli-mean-tokens'. 'bert-base-nli-mean-tokens' is selected due to robustness and high performance.
#
# 'bert-base-nli-mean-tokens' is a sentence-transformers model that maps sentences & paragraphs to a 768 dimensional dense vector space and can be used for tasks like clustering or semantic search. Using 'meat' as an examplary query test for category search, the model clearly generates more meaningful results than the previous fuzzy search approach.
# The full model architecture is shown below.

# %% [markdown]
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 128, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False,
#                 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False,
#                 'pooling_mode_mean_sqrt_len_tokens': False})
# )

# %% [markdown]
# First, a model is created using sentence_transformers.

# %%
from sentence_transformers import SentenceTransformer
model_name = 'bert-base-nli-mean-tokens'
# model_name = 'all-MiniLM-L6-v2'
# model_name = 'all-mpnet-base-v2'

model = SentenceTransformer(model_name)

# %% [markdown]
# Second, a sentence library coming from the desired field is created. In this example,

# %%
catDict = category['CATEGORY'].to_list()
catDict_vecs = model.encode(catDict)
print(catDict_vecs.shape)
# Out:
# (118, 768)

# %%
catDict_vecs
# Out:
# array([[-0.41283208,  0.19538327, -0.7930067 , ..., -0.17972049,
#          0.6738818 ,  0.5252664 ],
#        [-0.34384283,  0.20766301, -0.21792002, ..., -0.37926593,
#          0.02805232,  0.63666254],
#        [ 0.54358596,  0.8228612 ,  1.6034012 , ..., -0.3250906 ,
#          0.2267657 ,  0.13139722],
#        ...,
#        [-0.51006913,  1.0867724 , -0.1981626 , ..., -0.18807282,
#          0.77340156,  0.3120817 ],
#        [-0.18643278,  0.87110186,  0.6632734 , ..., -0.37362155,
#         -0.26959875,  0.02258943],
#        [ 0.26655945,  0.2495401 ,  1.5600967 , ...,  0.7145732 ,
#          0.29977995,  0.2982676 ]], dtype=float32)

# %% [markdown]
# Next, I applied the cosine similarity to calculate pair-wise similarity between the input string and all items in the category column.

# %%
from sklearn.metrics.pairwise import cosine_similarity

query = model.encode(['meat'])
print(query.shape)
cos = cosine_similarity(query, catDict_vecs)
similarity = category.copy()
similarity['Cosine'] = cos.reshape(-1, 1)

print(similarity.nlargest(20, 'Cosine')[['CATEGORY', 'Cosine']])
# Out:
# (1, 768)
#                        CATEGORY    Cosine
# 90                packaged meat  0.899200
# 47           jerky & dried meat  0.781604
# 72             plant-based meat  0.755113
# 105     frozen plant-based meat  0.655589
# 115                 frozen beef  0.632474
# 62                 food storage  0.621770
# 73                         eggs  0.609283
# 84                 dog supplies  0.607903
# 30                 soup & broth  0.600675
# 114              frozen chicken  0.570397
# 24       packaged meals & sides  0.570185
# 23                   condiments  0.569826
# 86               prepared meals  0.569633
# 63                       cheese  0.568969
# 85                pickled goods  0.568233
# 64            frozen vegetables  0.564005
# 17                     pretzels  0.547607
# 16   meal replacement beverages  0.529368
# 113               frozen turkey  0.528729
# 51                        bread  0.522049

# %% [markdown]
# The top 20 matched category makes more sense than the fuzzy search. Not only categories contain word 'meat' are identified, the rest high-score categories are food related, like eggs or forzen chicken. I will move forward to the actual problem using this pre-trained model.

# %% [markdown]
# ## 5. Search Tasks
#
# ### Task 1. Category Search
#
# The previous experiments show that we can query the category name and return similar categories. I will extend the search to the full table and return all offers under those similar categories in the order of relevance, namely similarity score. The next cell defines the query and how many anwser is desired.

# %%
def categorySearch(queryLst): 
    catDict = full['CATEGORY'].to_list()
    catDict_vecs = model.encode(catDict)
    similarity = full.copy()
    query = model.encode(queryLst)
    cos = cosine_similarity(query, catDict_vecs).round(4)
    for i, q in enumerate(queryLst): 
        similarity[q] = cos[i].reshape(-1, 1)
    out = similarity.copy()
    return out

# %%
queries = ['meat', 'coffee']
res = categorySearch(queries)

# %% [markdown]
# To display the result (stored in variable 'res'), I picked the top N based on similarity score from high to low. Note that duplicated offer is removed, as some offer may belong to multiple category. In the output, the last column, named as the query input string, denotes the similarity score. The output is stored in a csv file.

# %%
# Display the result, top N matched offer
def display(queryLst, df, N = 20): 
    for q in queryLst: 
#         print(f'The Top {N} offers by searching category {q}')
#         df.round(2)
        df.drop_duplicates(subset=['OFFER'], inplace = True)
        a = df.nlargest(N, q)[['OFFER', 'RETAILER', 'BRAND', 'CATEGORY', q]]
        a.rename(columns={q: "SCORE"}, inplace=True)
#         print(a.to_string(index=False))
#         print(a)
#         print()
        fname = f'Category Search Top {N} {q}.csv'
        a.to_csv(fname)

# %%
display(queries, res)

# %% [markdown]
# The result of top 20 offers by searching 'meat' in category is shown below.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# The result of top 20 offers by searching 'coffee' in category is shown below.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Task 2. Brand Search
#
# Similar to the category search. The difference is that I will search the brand in the brand table, and use the

# %%
def brandSearch(query): 
    """
    query: a string input of search in brand
    return: a dataframe with the last column is the similarity score between the query and brand in each row
    """
    
    brandDict = brand['BRAND'].to_list()
    brandDict_vecs = model.encode(brandDict)
    similarity = brand.copy()
    q = model.encode([query])
    cos = cosine_similarity(q, brandDict_vecs).round(4)
    similarity[query] = cos.reshape(-1, 1)
    out = similarity.copy()
    return out

# %%
def brandToCategory(df, query, cutoff = 0.9): 
    res['RECEIPTS'] = pd.to_numeric(res['RECEIPTS'])
    sortres = res.sort_values(by=[query, 'RECEIPTS'], ascending=[False, False])
    match = sortres[sortres[query] >= cutoff]
    print(match)
    return match['CATEGORY'].to_list(), match[query].to_list()

# %%
# Display the result, top N matched offer
def displayBrand(df, queryLst,  scores, cutoff = 0.8, N = 20): 
    df['RECEIPTS'] = pd.to_numeric(df['RECEIPTS'])
    df[queryLst] = df[queryLst]*scores
    df['SCORE'] = df[queryLst].max(axis=1)
    df.drop_duplicates(subset=['OFFER'], inplace = True)
    df.drop(columns=queryLst, inplace = True)
    sortdf = df.sort_values(by=['SCORE', 'RECEIPTS'], ascending=[False, False])
    print(sortdf.iloc[:N])
    fname = f'Category Search Top {N} {q}.csv'
    a.to_csv(fname)

# %%
brandQuery = 'Kroger'
res = brandSearch(brandQuery)

# %%
cats, b2catscore = brandToCategory(res, brandQuery)
n = len(cats)
res1 = categorySearch(cats)
# Out:
#        BRAND                             CATEGORY  RECEIPTS  Kroger
# 6     kroger                               bakery    251276     1.0
# 430   kroger                   household supplies      5255     1.0
# 473   kroger                                water      4823     1.0
# 554   kroger                         fruit juices      3985     1.0
# 601   kroger               carbonated soft drinks      3617     1.0
# 772   kroger  cereal, granola, & toaster pastries      2587     1.0
# 806   kroger                                chips      2439     1.0
# 1381  kroger                               coffee      1012     1.0
# 1770  kroger                      pasta & noodles       655     1.0
# 2079  kroger                          bath & body       475     1.0
# 2127  kroger                   sauces & marinades       452     1.0
# 2173  kroger                                bread       437     1.0
# 2658  kroger                     cooking & baking       300     1.0
# 2760  kroger                             crackers       273     1.0
# 2859  kroger          alfredo & white pasta sauce       256     1.0
# 3574  kroger                    nut butters & jam       156     1.0
# 4117  kroger                            dry pasta       114     1.0
# 4210  kroger                      red pasta sauce       108     1.0
# 4251  kroger                           condiments       105     1.0
# 4758  kroger                          drink mixes        78     1.0
# 5485  kroger                        puffed snacks        56     1.0
# 5605  kroger                                  tea        52     1.0
# 6085  kroger                     frozen breakfast        42     1.0
# 6721  kroger                            hair care        32     1.0
# 7107  kroger           meal replacement beverages        28     1.0
# 8072  kroger                  packaged vegetables        20     1.0
# 8365  kroger                            skin care        18     1.0

# %%
# print(cats)
displayBrand(res1, cats, b2catscore, 50)
# Out:
#                                                  OFFER             RETAILER  \
# 68   dr pepper regular or zero sugar strawberries a...  united supermarkets
# 677  mtn dew kickstart 16ounce 12 count select vari...               amazon
# 329  pepsico beverage 75ounce 10 pack select variet...               amazon
# 330  pepsico variety pack select varieties at amazo...               amazon
# 388    dove hand wash select varieties buy 2 at target               target
# 392          dove hand wash select varieties at target               target
# 713                   cheerios oat crunch berry cereal
# 505                     artesano buns buy 2 at walmart              walmart
# 695                      glad trash bags 4 or 8 gallon
# 699             glad forceflex max strength trash bags
# 683                                ballpark buns buy 2
# 79                                 barilla pesto sauce
# 83                barilla pasta select varieties buy 2
# 87                barilla pasta select varieties buy 3
# 91                barilla pasta select varieties buy 4
# 354            bai antioxidant 6 pack buy 2 at walmart              walmart
# 358                  bai antioxidant 6 pack at walmart              walmart
# 671         core hydration select varieties at walmart              walmart
# 672   core hydration select varieties buy 2 at walmart              walmart
# 723        general mills snacks select brands spend 10
#
#                  BRAND                             CATEGORY  \
# 68           dr pepper               carbonated soft drinks
# 677       mountain dew               carbonated soft drinks
# 329              pepsi               carbonated soft drinks
# 330              pepsi               carbonated soft drinks
# 388               dove                          bath & body
# 392               dove                          bath & body
# 713           cheerios  cereal, granola, & toaster pastries
# 505  sara lee artesano                               bakery
# 695               glad                   household supplies
# 699               glad                   household supplies
# 683  ball park pop ups                               bakery
# 79             barilla                                chips
# 83             barilla                                chips
# 87             barilla                                chips
# 91             barilla                                chips
# 354                bai                         fruit juices
# 358                bai                         fruit juices
# 671     core hydration                                water
# 672     core hydration                                water
# 723             bugles                                chips
#
#         PARENT_CATEGORY  RECEIPTS  SCORE
# 68            beverages     77880    1.0
# 677           beverages     68610    1.0
# 329           beverages     53604    1.0
# 330           beverages     53604    1.0
# 388   health & wellness     15821    1.0
# 392   health & wellness     15821    1.0
# 713              pantry     10876    1.0
# 505       deli & bakery      7912    1.0
# 695  household supplies      6822    1.0
# 699  household supplies      6822    1.0
# 683       deli & bakery      5920    1.0
# 79               snacks      5816    1.0
# 83               snacks      5816    1.0
# 87               snacks      5816    1.0
# 91               snacks      5816    1.0
# 354           beverages      4685    1.0
# 358           beverages      4685    1.0
# 671           beverages      4595    1.0
# 672           beverages      4595    1.0
# 723              snacks      3654    1.0

# %%
display(queries, res)

# %% [markdown]
# # 7. References:
#
# Sentence-Transformer library:
# https://www.sbert.net/docs/usage/semantic_textual_similarity.html
#
# bert-base-nli-mean-tokens model:
# https://huggingface.co/sentence-transformers/bert-base-nli-mean-tokens
#
# all-MiniLM-L6-v2 model
# https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2
#
# cosine similarity:
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.cosine_similarity.html#sklearn.metrics.pairwise.cosine_similarity
